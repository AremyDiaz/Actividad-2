# %%
#Importamos las librerias pandas, numpy y matplotlib respectivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Carga del archivo.csv
data = pd.read_csv("airbnb - Mexico.csv",encoding="ISO-8859-1") #, index_col=0
data
# Out:
#                  id                                               name  \
# 0      8.266910e+05                    Suite 7 - Suites Condesa Mexico
# 1      3.579700e+04                                        Villa Dante
# 2      5.239058e+07  Casa en privada con  vigilancia, estacionamiento.
# 3      8.267600e+05                   Suite 12 - Suites Condesa Mexico
# 4      4.461600e+04                                  CONDESA HAUS  B&B
# ...             ...                                                ...
# 21664  6.180000e+17  CÃ³modo Departamento en Satelite-Echegaray con...
# 21665  2.210710e+07                      GREAT & cozy flat in Satelite
# 21666  4.061781e+07                                             Blanca
# 21667  5.700000e+17                   Casa LimÃ³n. Confort y seguridad
# 21668  3.717560e+07  Linda casa con enorme jardÃ­n en zona residenc...
#
#          host_id                           host_name  neighbourhood_group  \
# 0        4326326                             Rodrigo                  NaN
# 1         153786                                Dici                  NaN
# 2      424060909                  Maria Carmen Marta                  NaN
# 3        4326326                             Rodrigo                  NaN
# 4         196253  Condesa Haus Bed & Breakfast  CDMX                  NaN
# ...          ...                                 ...                  ...
# 21664  442065952                             Ricardo                  NaN
# 21665  387195495                             Daniela                  NaN
# 21666   96471106                         Mary Carmen                  NaN
# 21667   30446640                              Ericka                  NaN
# 21668   51907431                             Cecilia                  NaN
#
#                neighbourhood    latitude  longitude        room_type    price  \
# 0                CuauhtÃ©moc   19.409150 -99.173210  Entire home/apt    850.0
# 1      Cuajimalpa de Morelos   19.382830 -99.271780  Entire home/apt   4056.0
# 2      Cuajimalpa de Morelos   19.395126 -99.277374     Private room    752.0
# 3                CuauhtÃ©moc   19.409150 -99.173210  Entire home/apt    971.0
# 4                CuauhtÃ©moc   19.411620 -99.177940  Entire home/apt  18000.0
# ...                      ...         ...        ...              ...      ...
# 21664           Azcapotzalco   19.499980 -99.226010  Entire home/apt    673.0
# 21665           Azcapotzalco  119.507870 -99.220670  Entire home/apt    897.0
# 21666           Azcapotzalco   19.507530 -99.225060  Entire home/apt    230.0
# 21667           Azcapotzalco   19.493360 -99.229090  Entire home/apt    690.0
# 21668           Azcapotzalco   19.490040 -99.230310  Entire home/apt   3228.0
#
#        minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0               180.0               18.0  11/05/2019               0.17
# 1                 1.0                0.0         NaN                NaN
# 2                 1.0                0.0         NaN                NaN
# 3                 4.0               17.0  15/03/2020               0.15
# 4                 1.0               56.0  05/06/2022               0.43
# ...               ...                ...         ...                ...
# 21664             1.0                3.0  29/05/2022               2.73
# 21665             2.0              107.0  07/02/2022               1.97
# 21666             1.0                5.0  31/12/2019               0.16
# 21667             3.0                0.0         NaN                NaN
# 21668             2.0               58.0  13/06/2022               1.66
#
#        calculated_host_listings_count  availability_365  number_of_reviews_ltm
# 0                                 6.0             325.0                    0.0
# 1                                 1.0             363.0                    0.0
# 2                                 1.0             365.0                    0.0
# 3                                 6.0             203.0                    0.0
# 4                                11.0             347.0                    7.0
# ...                               ...               ...                    ...
# 21664                            79.0               NaN                    3.0
# 21665                            11.0             314.0                   17.0
# 21666                             4.0             140.0                    0.0
# 21667                             1.0             354.0                    0.0
# 21668                             1.0              10.0                   20.0
#
# [21669 rows x 17 columns]

# %% [markdown]
# Métodos para reemplazar valores nulos en cada columna

# %%
#Copia del dataset original
data2 = data.copy()
data2
# Out:
#                  id                                               name  \
# 0      8.266910e+05                    Suite 7 - Suites Condesa Mexico
# 1      3.579700e+04                                        Villa Dante
# 2      5.239058e+07  Casa en privada con  vigilancia, estacionamiento.
# 3      8.267600e+05                   Suite 12 - Suites Condesa Mexico
# 4      4.461600e+04                                  CONDESA HAUS  B&B
# ...             ...                                                ...
# 21664  6.180000e+17  CÃ³modo Departamento en Satelite-Echegaray con...
# 21665  2.210710e+07                      GREAT & cozy flat in Satelite
# 21666  4.061781e+07                                             Blanca
# 21667  5.700000e+17                   Casa LimÃ³n. Confort y seguridad
# 21668  3.717560e+07  Linda casa con enorme jardÃ­n en zona residenc...
#
#          host_id                           host_name  neighbourhood_group  \
# 0        4326326                             Rodrigo                  NaN
# 1         153786                                Dici                  NaN
# 2      424060909                  Maria Carmen Marta                  NaN
# 3        4326326                             Rodrigo                  NaN
# 4         196253  Condesa Haus Bed & Breakfast  CDMX                  NaN
# ...          ...                                 ...                  ...
# 21664  442065952                             Ricardo                  NaN
# 21665  387195495                             Daniela                  NaN
# 21666   96471106                         Mary Carmen                  NaN
# 21667   30446640                              Ericka                  NaN
# 21668   51907431                             Cecilia                  NaN
#
#                neighbourhood    latitude  longitude        room_type    price  \
# 0                CuauhtÃ©moc   19.409150 -99.173210  Entire home/apt    850.0
# 1      Cuajimalpa de Morelos   19.382830 -99.271780  Entire home/apt   4056.0
# 2      Cuajimalpa de Morelos   19.395126 -99.277374     Private room    752.0
# 3                CuauhtÃ©moc   19.409150 -99.173210  Entire home/apt    971.0
# 4                CuauhtÃ©moc   19.411620 -99.177940  Entire home/apt  18000.0
# ...                      ...         ...        ...              ...      ...
# 21664           Azcapotzalco   19.499980 -99.226010  Entire home/apt    673.0
# 21665           Azcapotzalco  119.507870 -99.220670  Entire home/apt    897.0
# 21666           Azcapotzalco   19.507530 -99.225060  Entire home/apt    230.0
# 21667           Azcapotzalco   19.493360 -99.229090  Entire home/apt    690.0
# 21668           Azcapotzalco   19.490040 -99.230310  Entire home/apt   3228.0
#
#        minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0               180.0               18.0  11/05/2019               0.17
# 1                 1.0                0.0         NaN                NaN
# 2                 1.0                0.0         NaN                NaN
# 3                 4.0               17.0  15/03/2020               0.15
# 4                 1.0               56.0  05/06/2022               0.43
# ...               ...                ...         ...                ...
# 21664             1.0                3.0  29/05/2022               2.73
# 21665             2.0              107.0  07/02/2022               1.97
# 21666             1.0                5.0  31/12/2019               0.16
# 21667             3.0                0.0         NaN                NaN
# 21668             2.0               58.0  13/06/2022               1.66
#
#        calculated_host_listings_count  availability_365  number_of_reviews_ltm
# 0                                 6.0             325.0                    0.0
# 1                                 1.0             363.0                    0.0
# 2                                 1.0             365.0                    0.0
# 3                                 6.0             203.0                    0.0
# 4                                11.0             347.0                    7.0
# ...                               ...               ...                    ...
# 21664                            79.0               NaN                    3.0
# 21665                            11.0             314.0                   17.0
# 21666                             4.0             140.0                    0.0
# 21667                             1.0             354.0                    0.0
# 21668                             1.0              10.0                   20.0
#
# [21669 rows x 17 columns]

# %%
#Cuántos nulos hay por columna
valores_nulos=data2.isnull().sum()
valores_nulos
# Out:
# id                                    0
# name                                  3
# host_id                               0
# host_name                             7
# neighbourhood_group               21669
# neighbourhood                         6
# latitude                              4
# longitude                             2
# room_type                             9
# price                                 1
# minimum_nights                        1
# number_of_reviews                     4
# last_review                        3990
# reviews_per_month                  3990
# calculated_host_listings_count        2
# availability_365                      4
# number_of_reviews_ltm                 4
# dtype: int64

# %%
#“host_name”: Rellenar con el string "Unknown"
data2["host_name"]=data2["host_name"].fillna("Unknown")

# %%
#“neighbourhood”: Rellenar con el objeto "posterior" de la columna
data2["neighbourhood"]=data2["neighbourhood"].fillna(method="ffill")

# %%
#“latitude ”: Rellenar con el valor de “Media” de la columna con cinco decimales
data2["latitude"]=data2["latitude"].fillna(round(data["latitude"].mean(),5))

# %%
#“longitude”: Rellenar con el valor de “Mediana” de la columna con cinco decimales
data2["longitude"]=data2["longitude"].fillna(round(data["longitude"].median(),5))

# %%
#“room_type”: Rellenar con el string “Private room”
data2["room_type"] =data2["room_type"].fillna("Private room")

# %%
#“price”: Rellenar con el valor de “Media” de la columna
data2["price"]=data2["price"].fillna(round(data["price"].mean(),2))

# %%
#“minimum_nights”: Rellenar con el valor de “1”
data2["minimum_nights"]= data2["minimum_nights"].fillna(1)

# %%
#"number_of_reviews": Rellenar con el valor de “0”
data2["number_of_reviews"]= data2["number_of_reviews"].fillna(0)

# %%
#"last_review":Rellenar con "No_reviews" los faltantes
data2["last_review"] =data2["last_review"].fillna("No_reviews")

# %%
#"reviews_per_month": Rellenar con el valor de “Media” de la columna
data2["reviews_per_month"]=data2["reviews_per_month"].fillna(0)

# %%
#"calculated_host_listings_count": Rellenar con el valor de “1”
data2["calculated_host_listings_count"]= data2["calculated_host_listings_count"].fillna(1)

# %%
#"availability_365" y "number of reviews ltm": Rellenar con el objeto "anterior" de cada columna, respectivamente. 
data2["availability_365"]=data2["availability_365"].fillna(method="bfill")
data2["number_of_reviews_ltm"]=data2["number_of_reviews_ltm"].fillna(method="bfill")

# %%
#Métodos libres para las columnas faltantes
data2["name"]=data2["name"].fillna("Unknown")
data2["neighbourhood_group"]=data2["neighbourhood_group"].fillna("Unknown")

#Comprobación final
valores_nulos=data2.isnull().sum()
valores_nulos
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# number_of_reviews_ltm             0
# dtype: int64

# %% [markdown]
# TRATADO DE OUTLIERS

# %%
#Copia del dataset sin nulos
data3 = data2.copy()
data3
# Out:
#                  id                                               name  \
# 0      8.266910e+05                    Suite 7 - Suites Condesa Mexico
# 1      3.579700e+04                                        Villa Dante
# 2      5.239058e+07  Casa en privada con  vigilancia, estacionamiento.
# 3      8.267600e+05                   Suite 12 - Suites Condesa Mexico
# 4      4.461600e+04                                  CONDESA HAUS  B&B
# ...             ...                                                ...
# 21664  6.180000e+17  CÃ³modo Departamento en Satelite-Echegaray con...
# 21665  2.210710e+07                      GREAT & cozy flat in Satelite
# 21666  4.061781e+07                                             Blanca
# 21667  5.700000e+17                   Casa LimÃ³n. Confort y seguridad
# 21668  3.717560e+07  Linda casa con enorme jardÃ­n en zona residenc...
#
#          host_id                           host_name neighbourhood_group  \
# 0        4326326                             Rodrigo             Unknown
# 1         153786                                Dici             Unknown
# 2      424060909                  Maria Carmen Marta             Unknown
# 3        4326326                             Rodrigo             Unknown
# 4         196253  Condesa Haus Bed & Breakfast  CDMX             Unknown
# ...          ...                                 ...                 ...
# 21664  442065952                             Ricardo             Unknown
# 21665  387195495                             Daniela             Unknown
# 21666   96471106                         Mary Carmen             Unknown
# 21667   30446640                              Ericka             Unknown
# 21668   51907431                             Cecilia             Unknown
#
#                neighbourhood    latitude  longitude        room_type    price  \
# 0                CuauhtÃ©moc   19.409150 -99.173210  Entire home/apt    850.0
# 1      Cuajimalpa de Morelos   19.382830 -99.271780  Entire home/apt   4056.0
# 2      Cuajimalpa de Morelos   19.395126 -99.277374     Private room    752.0
# 3                CuauhtÃ©moc   19.409150 -99.173210  Entire home/apt    971.0
# 4                CuauhtÃ©moc   19.411620 -99.177940  Entire home/apt  18000.0
# ...                      ...         ...        ...              ...      ...
# 21664           Azcapotzalco   19.499980 -99.226010  Entire home/apt    673.0
# 21665           Azcapotzalco  119.507870 -99.220670  Entire home/apt    897.0
# 21666           Azcapotzalco   19.507530 -99.225060  Entire home/apt    230.0
# 21667           Azcapotzalco   19.493360 -99.229090  Entire home/apt    690.0
# 21668           Azcapotzalco   19.490040 -99.230310  Entire home/apt   3228.0
#
#        minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 0               180.0               18.0  11/05/2019               0.17
# 1                 1.0                0.0  No_reviews               0.00
# 2                 1.0                0.0  No_reviews               0.00
# 3                 4.0               17.0  15/03/2020               0.15
# 4                 1.0               56.0  05/06/2022               0.43
# ...               ...                ...         ...                ...
# 21664             1.0                3.0  29/05/2022               2.73
# 21665             2.0              107.0  07/02/2022               1.97
# 21666             1.0                5.0  31/12/2019               0.16
# 21667             3.0                0.0  No_reviews               0.00
# 21668             2.0               58.0  13/06/2022               1.66
#
#        calculated_host_listings_count  availability_365  number_of_reviews_ltm
# 0                                 6.0             325.0                    0.0
# 1                                 1.0             363.0                    0.0
# 2                                 1.0             365.0                    0.0
# 3                                 6.0             203.0                    0.0
# 4                                11.0             347.0                    7.0
# ...                               ...               ...                    ...
# 21664                            79.0             314.0                    3.0
# 21665                            11.0             314.0                   17.0
# 21666                             4.0             140.0                    0.0
# 21667                             1.0             354.0                    0.0
# 21668                             1.0              10.0                   20.0
#
# [21669 rows x 17 columns]

# %% [markdown]
# Distribución normal

# %%
#Valores extremos: límite superior y límite inferior.
#Variable: latitude.
x1=data3["latitude"]
LS1= x1.mean() + 3*x1.std()
LI1= x1.mean() - 3*x1.std()
print("Limite superior permitido", LS1)
print("Limite inferior permitido", LI1)
# Out:
# Limite superior permitido 22.0250106625759
# Limite inferior permitido 16.795013605226025

# %%
#Outliers de latitude.
outliers_latitude = data3[(x1>LS1)|(x1<LI1)]
outliers_latitude
# Out:
#                id                                 name    host_id  \
# 12741  46757982.0  Residencia Master Suite con Terraza  375169008
# 21665  22107097.0        GREAT & cozy flat in Satelite  387195495
#
#          host_name neighbourhood_group   neighbourhood   latitude  longitude  \
# 12741  Residencias             Unknown  Benito JuÃ¡rez   99.39291  -99.17623
# 21665      Daniela             Unknown    Azcapotzalco  119.50787  -99.22067
#
#              room_type   price  minimum_nights  number_of_reviews last_review  \
# 12741  Entire home/apt  3678.0             2.0                0.0  No_reviews
# 21665  Entire home/apt   897.0             2.0              107.0  07/02/2022
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# 12741               0.00                            25.0             337.0
# 21665               1.97                            11.0             314.0
#
#        number_of_reviews_ltm
# 12741                    0.0
# 21665                   17.0

# %%
#Diagrama de caja: latitude.
fig1 = plt.figure(figsize =(5, 3))
plt.boxplot(data3["latitude"]) #boxplot() usa iqr
plt.title("Outliers de latitude")
plt.show() #diagrama para visualizar outliers. En este caso no serán tratados, porque el dato indica ubicación.

# %%
#Valores extremos: límite superior y límite inferior.
#Variable: longitude.
x2=data3["longitude"]
LS2= x2.mean() + 3*x2.std()
LI2= x2.mean() - 3*x2.std()
print("Limite superior permitido", LS2)
print("Limite inferior permitido", LI2)
# Out:
# Limite superior permitido -89.00097105092638
# Limite inferior permitido -109.3286521073947

# %%
#Outliers de longitude.
outliers_longitude = data3[(x2>LS2)|(x2<LI2)]
outliers_longitude
# Out:
#                id                                      name    host_id  \
# 12003  45519073.0  Spacious 3BR/3.5BATH in heart of Condesa    2593419
# 12009  45454474.0      Bonito departamento cerca del Ãngel  303864680
#
#          host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 12003        Katie             Unknown   CuauhtÃ©moc  19.41882 -399.17598
# 12009  Leidi Laura             Unknown   CuauhtÃ©moc  19.42738  299.16998
#
#              room_type   price  minimum_nights  number_of_reviews last_review  \
# 12003  Entire home/apt  3040.0             3.0               48.0  22/05/2022
# 12009  Entire home/apt  2670.0             1.0                6.0  09/01/2022
#
#        reviews_per_month  calculated_host_listings_count  availability_365  \
# 12003               2.65                             1.0             165.0
# 12009               0.28                             8.0             359.0
#
#        number_of_reviews_ltm
# 12003                   44.0
# 12009                    1.0

# %%
#Diagrama de caja: longitude.
fig2 = plt.figure(figsize =(5, 3))
plt.boxplot(data3["longitude"]) #boxplot() usa iqr
plt.title("Outliers de longitude")
plt.show() #diagrama para visualizar outliers. En este caso no serán tratados, porque el dato indica ubicación.

# %%
#Valores extremos: límite superior y límite inferior.
#Variable: price.
x3=data3["price"]
LS3= x3.mean() + 3*x3.std()
LI3= x3.mean() - 3*x3.std()
print("Limite superior permitido", LS3)
print("Limite inferior permitido", LI3)
# Out:
# Limite superior permitido 25905.958109254956
# Limite inferior permitido -23004.991984376094

# %%
#Outliers de price.
outliers_price = data3[(x3>LS3)|(x3<LI3)]
outliers_price
# Out:
#                  id                                               name  \
# 724    6.871835e+06                               WTC MÃ©xico Napoles.
# 1554   1.385978e+07  Grand Tower 2 queen bedroom,amenities 1block C...
# 1906   1.542343e+07                  HabitaciÃ³n con excelente paisaje
# 2096   1.622930e+07       Apartamento cerca de Carso, Antara, Polanco,
# 2125   1.639185e+07       Spacious apartment in the heart of the city!
# 2513   1.794602e+07               Antara, Polanco, Carso, Apartamento.
# 3125   1.994540e+07                                       Master Suite
# 3265   2.058624e+07                          Obelisk Suite 1 recÃ¡mara
# 4279   2.389552e+07           HabitaciÃ³n a 40min del centro historico
# 4315   2.349835e+07               CASA EN PEDREGAL , COLONIAL MEXICANO
# 5345   2.795386e+07                                         Polarea Cc
# 6032   3.003987e+07                                           Rombo II
# 6050   3.004331e+07                                           Rombo IV
# 6333   3.144444e+07                                          No activo
# 6934   3.291760e+07                       Nuevo Polanco. Nice and Cozy
# 7129   3.339365e+07               HabitaciÃ³n en Blas Pascal - Polanco
# 7837   3.537749e+07       Polanco Antara, Carso apartamento muy lindo.
# 8117   3.660852e+07            Renta departamento en colonia del valle
# 8359   3.677330e+07                          Sunny and  charming oasis
# 9661   4.025673e+07  Colorful hipster house (up to 5 people) in Con...
# 10194  4.161536e+07                                    Casa Vertientes
# 10277  4.182248e+07                      Departamento para estudiantes
# 10706  4.254286e+07   Enjoy  Polanco, the best neighborhood as a local
# 10745  4.256240e+07  Locacion de lujo para filmaciones, PH Condesa ...
# 11007  4.306909e+07    Luminoso,Ã¡mplio,encantadora terraza en la Roma
# 11098  4.352751e+07  3 Bedroom Apartment in Centro, CDMX [Mexico City]
# 11253  4.391546e+07            Lindo Departamento en Tizapan San Angel
# 11603  4.448086e+07                               Recamaras amuebladas
# 12079  4.554905e+07           RENTA DEPA NUEVO en la col. CuauhtÃ©moc!
# 12625  4.622517e+07  Hermosa casona cerca San Ãngel Capacidad hast...
# 13884  4.897852e+07                                    Casa tipo villa
# 13989  4.919613e+07                                   Depto Singapur 2
# 14883  5.092434e+07                Mr. W | Uma Casa | 9 Premium Suites
# 15503  5.179996e+07                     Espacio ÃNICO en la Del Valle
# 15721  5.205597e+07  Hospital 20 de noviembre, Universidad, Del Valle.
# 15758  5.209695e+07  Love bedroom in magic pet friendly villa - Con...
# 16081  5.244045e+07    VH | GREAT HOUSE 27 PAX+GYM+WIFI+TERRACES | 176
# 16151  5.251835e+07   Hotel la casa de la luna. Centro Historico CDMX.
# 16153  5.262052e+07         Hotel Casa de la luna. Comodo y agradable.
# 16648  5.301217e+07                          ROOF 44. TOTAL EXPERIENCE
# 17192  5.366558e+07    Condesa House on Avenida Amsterdam - Casa Bravo
# 17569  5.411150e+07    Hermoso condominio Polanco la mejor ubicaciÃ³n.
# 17951  5.390000e+17  3br in  Historic Mansion Steps from the Cathedral
# 18239  5.570000e+17  Departamento al sur d Ciudad de MÃ©xico UnamPe...
# 18486  5.690000e+17      Hermoso departamento con excelente ubicaciÃ³n
# 19099  5.900000e+17   Casa Hedera - Luxury Oasis 9 BR Boutique House!!
#
#          host_id      host_name neighbourhood_group          neighbourhood  \
# 724     36014559          Jorge             Unknown         Benito JuÃ¡rez
# 1554    42599988         Hector             Unknown         Miguel Hidalgo
# 1906    98850558    Tania Anahi             Unknown             Iztapalapa
# 2096   130445271          Mario             Unknown         Miguel Hidalgo
# 2125    26762960   Juan Antonio             Unknown            CuauhtÃ©moc
# 2513   130445271          Mario             Unknown         Miguel Hidalgo
# 3125   141354058         Suites             Unknown         Miguel Hidalgo
# 3265   141354058         Suites             Unknown         Miguel Hidalgo
# 4279   173103110           Ines             Unknown             Iztapalapa
# 4315    28935792        Paulina             Unknown       Ãlvaro ObregÃ³n
# 5345   130445271          Mario             Unknown         Miguel Hidalgo
# 6032   207171317           Casa             Unknown  Cuajimalpa de Morelos
# 6050   207171317           Casa             Unknown         Miguel Hidalgo
# 6333   107194368       Cristina             Unknown            CuauhtÃ©moc
# 6934   130445271          Mario             Unknown         Miguel Hidalgo
# 7129   120938169        Rodrigo             Unknown         Miguel Hidalgo
# 7837   130445271          Mario             Unknown         Miguel Hidalgo
# 8117   264094203        Abraham             Unknown         Benito JuÃ¡rez
# 8359    53749834          Yurik             Unknown            CuauhtÃ©moc
# 9661   310905307      Francisco             Unknown            CuauhtÃ©moc
# 10194  328124508          Maria             Unknown         Miguel Hidalgo
# 10277  330524121         Manuel             Unknown      Gustavo A. Madero
# 10706  158757829        Alberto             Unknown         Miguel Hidalgo
# 10745   93861150           Juan             Unknown            CuauhtÃ©moc
# 11007   53749834          Yurik             Unknown            CuauhtÃ©moc
# 11098  346685643        Getgopi             Unknown            CuauhtÃ©moc
# 11253   28935792        Paulina             Unknown       Ãlvaro ObregÃ³n
# 11603  359602500        Vanessa             Unknown         Benito JuÃ¡rez
# 12079   28935792        Paulina             Unknown            CuauhtÃ©moc
# 12625  110805631          Diana             Unknown       Ãlvaro ObregÃ³n
# 13884  180895600         Sergio             Unknown                Tlalpan
# 13989  357490287      Alejandro             Unknown         Miguel Hidalgo
# 14883   10764020          Mr. W             Unknown         Miguel Hidalgo
# 15503  103629467          Marco             Unknown         Benito JuÃ¡rez
# 15721  130445271          Mario             Unknown         Benito JuÃ¡rez
# 15758  310905307      Francisco             Unknown            CuauhtÃ©moc
# 16081  382880251         Carcho             Unknown            CuauhtÃ©moc
# 16151  425087780           Elia             Unknown            CuauhtÃ©moc
# 16153  425087780           Elia             Unknown            CuauhtÃ©moc
# 16648  404525377  Jorge AdriÃ¡n             Unknown         Benito JuÃ¡rez
# 17192  361397783           Jeff             Unknown            CuauhtÃ©moc
# 17569   23301164         Silvia             Unknown         Miguel Hidalgo
# 17951   10764020          Mr. W             Unknown            CuauhtÃ©moc
# 18239  155943365           Jony             Unknown                Tlalpan
# 18486  446552509            Ada             Unknown            CuauhtÃ©moc
# 19099   41963013         Hector             Unknown         Miguel Hidalgo
#
#         latitude  longitude        room_type     price  minimum_nights  \
# 724    19.396140 -99.173710  Entire home/apt   31386.0             1.0
# 1554   19.441990 -99.201380  Entire home/apt   26251.0             2.0
# 1906   19.371820 -99.074390     Private room   30422.0             5.0
# 2096   19.444490 -99.203990  Entire home/apt   99998.0             2.0
# 2125   19.429610 -99.158760  Entire home/apt   50000.0             1.0
# 2513   19.441670 -99.197490  Entire home/apt   57785.0             2.0
# 3125   19.427230 -99.196670       Hotel room   40386.0             1.0
# 3265   19.428380 -99.197390     Private room   40386.0             1.0
# 4279   19.328990 -98.976970     Private room  350000.0             1.0
# 4315   19.326260 -99.206030  Entire home/apt   72568.0           160.0
# 5345   19.446480 -99.203670  Entire home/apt   99998.0             2.0
# 6032   19.402410 -99.255840  Entire home/apt   40158.0             2.0
# 6050   19.402710 -99.253640  Entire home/apt   56383.0             2.0
# 6333   19.429420 -99.171700  Entire home/apt   55000.0             2.0
# 6934   19.439070 -99.176190  Entire home/apt   88888.0             2.0
# 7129   19.437220 -99.212470     Private room   30000.0             1.0
# 7837   19.441070 -99.197120  Entire home/apt  999998.0             3.0
# 8117   19.381350 -99.165960  Entire home/apt   26000.0           365.0
# 8359   19.418780 -99.173150  Entire home/apt  140000.0             2.0
# 9661   19.415870 -99.176800  Entire home/apt   45000.0             2.0
# 10194  19.412010 -99.229440  Entire home/apt  180000.0             2.0
# 10277  19.509020 -99.119480     Private room   43468.0            17.0
# 10706  19.435860 -99.189200  Entire home/apt   29966.0             1.0
# 10745  19.413440 -99.173900     Private room   45535.0             1.0
# 11007  19.421660 -99.154110  Entire home/apt  199999.0           360.0
# 11098  19.437080 -99.130070  Entire home/apt   33609.0             5.0
# 11253  19.336910 -99.204400  Entire home/apt   40563.0             7.0
# 11603  19.395280 -99.161750     Private room   81126.0            15.0
# 12079  19.431100 -99.162090  Entire home/apt   30289.0            30.0
# 12625  19.360590 -99.187380  Entire home/apt   28000.0             1.0
# 13884  19.269510 -99.171290     Private room  101408.0             2.0
# 13989  19.440870 -99.203310  Entire home/apt   60579.0             2.0
# 14883  19.426950 -99.213660     Private room   50704.0             1.0
# 15503  19.372840 -99.174130  Entire home/apt   40563.0            90.0
# 15721  19.372140 -99.167480  Entire home/apt   99998.0             3.0
# 15758  19.416260 -99.178060     Private room   45000.0             2.0
# 16081  19.431843 -99.168762  Entire home/apt   30347.0             1.0
# 16151  19.429230 -99.138260     Private room   32000.0             1.0
# 16153  19.429830 -99.140000     Private room   85000.0             1.0
# 16648  19.399050 -99.162270  Entire home/apt   38000.0             1.0
# 17192  19.412490 -99.169910  Entire home/apt  150000.0             3.0
# 17569  19.427910 -99.189640  Entire home/apt   50000.0             1.0
# 17951  19.434320 -99.130790     Private room  201929.0             2.0
# 18239  19.284810 -99.195480  Entire home/apt   75000.0             1.0
# 18486  19.406200 -99.144750      Shared room   28000.0             1.0
# 19099  19.430150 -99.209360  Entire home/apt   26366.0             1.0
#
#        number_of_reviews last_review  reviews_per_month  \
# 724                 40.0  22/06/2017               0.47
# 1554                 4.0  01/01/2017               0.06
# 1906                 0.0  No_reviews               0.00
# 2096                83.0  29/11/2021               1.28
# 2125                27.0  01/05/2017               0.40
# 2513                96.0  10/06/2022               1.51
# 3125                11.0  06/11/2021               0.19
# 3265                 1.0  21/11/2018               0.02
# 4279                 0.0  No_reviews               0.00
# 4315                 0.0  No_reviews               0.00
# 5345                 8.0  02/01/2019               0.18
# 6032                 0.0  No_reviews               0.00
# 6050                 2.0  09/10/2019               0.06
# 6333                 0.0  No_reviews               0.00
# 6934                42.0  25/02/2022               1.05
# 7129                 4.0  20/06/2019               0.10
# 7837                 1.0  19/08/2019               0.03
# 8117                 0.0  No_reviews               0.00
# 8359                26.0  26/07/2021               0.75
# 9661                 1.0  07/08/2020               0.04
# 10194                0.0  No_reviews               0.00
# 10277                0.0  No_reviews               0.00
# 10706                0.0  No_reviews               0.00
# 10745                0.0  No_reviews               0.00
# 11007                3.0  31/08/2020               0.11
# 11098                0.0  No_reviews               0.00
# 11253                1.0  03/07/2020               0.04
# 11603                0.0  No_reviews               0.00
# 12079                0.0  No_reviews               0.00
# 12625                0.0  No_reviews               0.00
# 13884                0.0  No_reviews               0.00
# 13989                0.0  No_reviews               0.00
# 14883                1.0  09/05/2022               0.68
# 15503                0.0  No_reviews               0.00
# 15721               20.0  15/04/2022               2.11
# 15758                2.0  12/09/2021               0.21
# 16081               11.0  03/06/2022               1.25
# 16151                0.0  No_reviews               0.00
# 16153                0.0  No_reviews               0.00
# 16648                0.0  No_reviews               0.00
# 17192                1.0  01/01/2022               0.17
# 17569                0.0  No_reviews               0.00
# 17951                2.0  23/04/2022               0.72
# 18239                0.0  No_reviews               0.00
# 18486                0.0  No_reviews               0.00
# 19099                0.0  No_reviews               0.00
#
#        calculated_host_listings_count  availability_365  number_of_reviews_ltm
# 724                               1.0             365.0                    0.0
# 1554                              1.0             365.0                    0.0
# 1906                              1.0             309.0                    0.0
# 2096                              8.0             364.0                    7.0
# 2125                              1.0             202.0                    0.0
# 2513                              8.0             358.0                    3.0
# 3125                              2.0             360.0                    1.0
# 3265                              2.0             361.0                    0.0
# 4279                              1.0             365.0                    0.0
# 4315                              4.0             180.0                    0.0
# 5345                              8.0             365.0                    0.0
# 6032                              2.0             202.0                    0.0
# 6050                              2.0              81.0                    0.0
# 6333                              1.0             178.0                    0.0
# 6934                              8.0             365.0                   15.0
# 7129                              1.0             140.0                    0.0
# 7837                              8.0             359.0                    0.0
# 8117                              1.0             365.0                    0.0
# 8359                              2.0             219.0                    4.0
# 9661                              2.0             365.0                    0.0
# 10194                             1.0             226.0                    0.0
# 10277                             1.0             365.0                    0.0
# 10706                             1.0               0.0                    0.0
# 10745                             1.0             325.0                    0.0
# 11007                             2.0             365.0                    0.0
# 11098                             1.0             358.0                    0.0
# 11253                             4.0             365.0                    0.0
# 11603                             1.0             365.0                    0.0
# 12079                             4.0             365.0                    0.0
# 12625                            15.0             364.0                    0.0
# 13884                             2.0              29.0                    0.0
# 13989                             1.0             365.0                    0.0
# 14883                           170.0             362.0                    1.0
# 15503                             1.0             180.0                    0.0
# 15721                             8.0             365.0                   20.0
# 15758                             2.0             365.0                    2.0
# 16081                            44.0               0.0                   11.0
# 16151                             4.0             364.0                    0.0
# 16153                             4.0             364.0                    0.0
# 16648                             1.0             359.0                    0.0
# 17192                             1.0             203.0                    1.0
# 17569                             2.0             364.0                    0.0
# 17951                           170.0             173.0                    2.0
# 18239                             1.0             365.0                    0.0
# 18486                             1.0             365.0                    0.0
# 19099                            41.0             282.0                    0.0

# %%
#Diagrama de caja: price.
fig3 = plt.figure(figsize =(5, 3))
plt.boxplot(data3["price"]) #boxplot() usa iqr
plt.title("Outliers de price")
plt.show()

# %%
#Valores extremos: límite superior y límite inferior.
#Variable: minimum_nights.
x4=data3["minimum_nights"]
LS4= x4.mean() + 3*x4.std()
LI4= x4.mean() - 3*x4.std()
print("Limite superior permitido", LS4)
print("Limite inferior permitido", LI4)
# Out:
# Limite superior permitido 85.28175780845893
# Limite inferior permitido -75.59916977947745

# %%
#Outliers de minimum_nights.
outliers_minimum_nights = data3[(x4>LS4)|(x4<LI4)]
outliers_minimum_nights
# Out:
#                id                                             name    host_id  \
# 0        826691.0                  Suite 7 - Suites Condesa Mexico    4326326
# 73      1187817.0                  Suite 1 - Suites Condesa Mexico    4326326
# 169      525618.0                 Beautiful Colonia Roma apartment    2566629
# 183     1798108.0  Near park Mexico. Brilliant and renovated flat!    1595855
# 326     4604145.0                  Suite 3 - Suites Condesa Mexico    4326326
# ...           ...                                              ...        ...
# 21317  48096905.0                                   Se renta Suite  387846773
# 21350  23741236.0                     Interlomas Perfect Apartment   10358425
# 21527  17732363.0                         DEPARTAMENTOS AMUEBLADOS  120918514
# 21545  31946858.0    Bonito cuarto privado para dama en La Florida  146368828
# 21567  36036705.0       Departamento Remodelado en Renta Echegaray  271110724
#
#                host_name neighbourhood_group          neighbourhood  latitude  \
# 0                Rodrigo             Unknown            CuauhtÃ©moc  19.40915
# 73               Rodrigo             Unknown            CuauhtÃ©moc  19.40915
# 169    Alejandra & Billy             Unknown            CuauhtÃ©moc  19.41588
# 183                Yahir             Unknown            CuauhtÃ©moc  19.41638
# 326              Rodrigo             Unknown            CuauhtÃ©moc  19.40904
# ...                  ...                 ...                    ...       ...
# 21317               Gina             Unknown  Cuajimalpa de Morelos  19.39884
# 21350           Penelope             Unknown  Cuajimalpa de Morelos  19.38465
# 21527           Fernando             Unknown      Gustavo A. Madero  19.53648
# 21545          Alexandra             Unknown           Azcapotzalco  19.49877
# 21567                 Il             Unknown           Azcapotzalco  19.48724
#
#        longitude        room_type    price  minimum_nights  number_of_reviews  \
# 0      -99.17321  Entire home/apt    850.0           180.0               18.0
# 73     -99.17321  Entire home/apt    900.0           120.0               50.0
# 169    -99.15981  Entire home/apt   2308.0           360.0               26.0
# 183    -99.16868  Entire home/apt   1171.0           180.0                8.0
# 326    -99.17327  Entire home/apt    800.0           179.0               20.0
# ...          ...              ...      ...             ...                ...
# 21317  -99.27079  Entire home/apt    385.0           365.0                0.0
# 21350  -99.29423  Entire home/apt   1806.0           180.0                8.0
# 21527  -99.18892     Private room    250.0           180.0                0.0
# 21545  -99.23388     Private room    250.0           170.0                0.0
# 21567  -99.22519  Entire home/apt  10000.0           180.0                0.0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 0      11/05/2019               0.17                             6.0
# 73     24/11/2018               0.45                             6.0
# 169    10/09/2018               0.22                             1.0
# 183    09/05/2021               0.08                             1.0
# 326    07/01/2019               0.24                             6.0
# ...           ...                ...                             ...
# 21317  No_reviews               0.00                             1.0
# 21350  26/02/2021               0.16                             1.0
# 21527  No_reviews               0.00                             2.0
# 21545  No_reviews               0.00                             1.0
# 21567  No_reviews               0.00                             1.0
#
#        availability_365  number_of_reviews_ltm
# 0                 325.0                    0.0
# 73                364.0                    0.0
# 169               264.0                    0.0
# 183               365.0                    0.0
# 326               364.0                    0.0
# ...                 ...                    ...
# 21317             365.0                    0.0
# 21350             352.0                    0.0
# 21527             365.0                    0.0
# 21545             365.0                    0.0
# 21567             365.0                    0.0
#
# [176 rows x 17 columns]

# %%
#Diagrama de caja: minimum_nights.
fig4 = plt.figure(figsize =(5, 3))
plt.boxplot(data3["minimum_nights"]) #boxplot() usa iqr
plt.title("Outliers de minimum_nights")
plt.show()

# %%
#Valores extremos: límite superior y límite inferior.
#Variable: number_of_reviews.
x5=data3["number_of_reviews"]
LS5= x5.mean() + 3*x5.std()
LI5= x5.mean() - 3*x5.std()
print("Limite superior permitido", LS5)
print("Limite inferior permitido", LI5)
# Out:
# Limite superior permitido 200.14693399059885
# Limite inferior permitido -136.9106978929478

# %%
#Outliers de minimum_nights.
outliers_number_of_reviews = data3[(x5>LS5)|(x5<LI5)]
outliers_number_of_reviews
# Out:
#                id                                               name  \
# 23       883511.0  Cozy House with Roofterrace group 29 pax Cente...
# 31       165772.0       BEST 4BR 4 BH HOUSE IN S. MIGUEL CHAPULTEPEC
# 32      2083241.0  Condesa Apartment in 1920s Landmarked Art Nouv...
# 33       939721.0       Radiant Apartment with Terrace in Roma Norte
# 35       997247.0                NEW! HISTORIC BUILDING -BEST STREET
# ...           ...                                                ...
# 16325  52769775.0  Charming & Cozy 1BR Apt | 2 Rooftops+Gym+B/Center
# 16326  52769810.0  2BR Apt w/Balcony |Rooftop-FirePit+Best Views+Gym
# 16327  52769824.0  Wonderful 2BR Apt |Polanco|2 Rooftops+Gym+B/Ce...
# 16328  52769833.0  Cute & Intimate Apt | Gym+2 Rooftops+Fire Pit+...
# 16919  53418457.0           Ayenda Terraza 158, Double Standard Room
#
#          host_id    host_name neighbourhood_group   neighbourhood   latitude  \
# 23       3777702      Abraham             Unknown     CuauhtÃ©moc  19.442070
# 31        790208   Maria Jose             Unknown  Miguel Hidalgo  19.408260
# 32       8282570       Thomas             Unknown     CuauhtÃ©moc  19.415300
# 33       4821807         Alex             Unknown     CuauhtÃ©moc  19.422880
# 35       5479592      Lorenzo             Unknown     CuauhtÃ©moc  19.414340
# ...          ...          ...                 ...             ...        ...
# 16325  335393886         Uliv             Unknown  Miguel Hidalgo  19.438433
# 16326  335393886         Uliv             Unknown  Miguel Hidalgo  19.438433
# 16327  335393886         Uliv             Unknown  Miguel Hidalgo  19.438433
# 16328  335393886         Uliv             Unknown  Miguel Hidalgo  19.438433
# 16919  398834109  Terraza 158             Unknown  Miguel Hidalgo  19.430376
#
#        longitude        room_type   price  minimum_nights  number_of_reviews  \
# 23    -99.147970  Entire home/apt  2827.0             1.0              209.0
# 31    -99.186590  Entire home/apt  3837.0             2.0              278.0
# 32    -99.167630  Entire home/apt  1600.0             3.0              246.0
# 33    -99.154880  Entire home/apt  1572.0             3.0              458.0
# 35    -99.158570  Entire home/apt  1921.0             2.0              394.0
# ...          ...              ...     ...             ...                ...
# 16325 -99.192001  Entire home/apt  1558.0             1.0              208.0
# 16326 -99.192001  Entire home/apt  2104.0             1.0              286.0
# 16327 -99.192001  Entire home/apt  1900.0             1.0              272.0
# 16328 -99.192001  Entire home/apt  1612.0             1.0              277.0
# 16919 -99.178917     Private room   969.0             1.0              372.0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 23     06/06/2022               1.83                             6.0
# 31     30/05/2022               2.09                             6.0
# 32     04/06/2022               2.62                             3.0
# 33     06/06/2022               4.09                             4.0
# 35     30/05/2022               3.56                             1.0
# ...           ...                ...                             ...
# 16325  19/06/2022              24.96                            11.0
# 16326  19/06/2022              34.46                            11.0
# 16327  19/06/2022              32.64                            11.0
# 16328  18/06/2022              33.24                            11.0
# 16919  21/06/2022              52.15                             3.0
#
#        availability_365  number_of_reviews_ltm
# 23                249.0                   27.0
# 31                231.0                    8.0
# 32                140.0                   41.0
# 33                171.0                   49.0
# 35                327.0                   34.0
# ...                 ...                    ...
# 16325             364.0                  208.0
# 16326             365.0                  286.0
# 16327             365.0                  272.0
# 16328             365.0                  277.0
# 16919             361.0                  372.0
#
# [532 rows x 17 columns]

# %%
#Diagrama de caja: number_of_reviews.
fig5 = plt.figure(figsize =(5, 3))
plt.boxplot(data3["number_of_reviews"]) #boxplot() usa iqr
plt.title("Outliers de number_of_reviews")
plt.show()

# %%
#Valores extremos: límite superior y límite inferior.
#Variable: reviews_per_month.
x6=data3["reviews_per_month"]
LS6= x6.mean() + 3*x6.std()
LI6= x6.mean() - 3*x6.std()
print("Limite superior permitido", LS6)
print("Limite inferior permitido", LI6)
# Out:
# Limite superior permitido 7.056944987005924
# Limite inferior permitido -4.468964923320474

# %%
#Outliers de reviews_per_month.
outliers_reviews_per_month = data3[(x6>LS6)|(x6<LI6)]
outliers_reviews_per_month
# Out:
#                  id                                               name  \
# 1488   1.339804e+07  Depa privado para visitar monumentos emblemÃ¡t...
# 1674   1.415008e+07                              5 min to CDMX airport
# 1675   1.415013e+07                              5 min to CDMX airport
# 1785   1.432096e+07      Trendy and cozy apartment at CondesaÂ´s heart
# 2247   1.702510e+07     Bedroom near the airport of the city of Mexico
# ...             ...                                                ...
# 20226  6.270000e+17                      Danni's sunny & spacious Home
# 20232  6.290000e+17                       Apt Monet | Polanco | Antara
# 20255  6.310000e+17  Loft Suite JuÃ¡rez Reforma a tres cuadras del ...
# 20352  6.300000e+17  302â
#  LA MEJOR UBICACIÃN ! REFORMA / CHAPULT...
# 20427  6.330000e+17  Executive Apt |Great Location|Gym+B/Center+Roo...
#
#          host_id   host_name neighbourhood_group        neighbourhood  \
# 1488    70937648      Victor             Unknown          CuauhtÃ©moc
# 1674    10644799      Benito             Unknown  Venustiano Carranza
# 1675    10644799      Benito             Unknown  Venustiano Carranza
# 1785    60203647  Alex Y May             Unknown          CuauhtÃ©moc
# 2247   114195033     Rogelio             Unknown            Iztacalco
# ...          ...         ...                 ...                  ...
# 20226  310183141    Kristina             Unknown          CuauhtÃ©moc
# 20232  338026302       Edith             Unknown       Miguel Hidalgo
# 20255  245618000   Alejandra             Unknown          CuauhtÃ©moc
# 20352  452872126  Rio Hudson             Unknown       Miguel Hidalgo
# 20427  375454819        Uliv             Unknown          CuauhtÃ©moc
#
#         latitude  longitude        room_type   price  minimum_nights  \
# 1488   19.434310 -99.145940  Entire home/apt  1217.0             1.0
# 1674   19.439490 -99.087690  Entire home/apt   385.0             1.0
# 1675   19.439490 -99.087690  Entire home/apt   406.0             1.0
# 1785   19.412820 -99.175380  Entire home/apt  1263.0             1.0
# 2247   19.413940 -99.057300     Private room   280.0             1.0
# ...          ...        ...              ...     ...             ...
# 20226  19.417520 -99.177640     Private room   351.0             1.0
# 20232  19.437130 -99.202400  Entire home/apt  1101.0             1.0
# 20255  19.423483 -99.168915  Entire home/apt   970.0             1.0
# 20352  19.427580 -99.175510  Entire home/apt  1200.0             2.0
# 20427  19.407688 -99.173706  Entire home/apt  1681.0             1.0
#
#        number_of_reviews last_review  reviews_per_month  \
# 1488               529.0  19/06/2022               7.37
# 1674               579.0  08/05/2022               8.17
# 1675               552.0  30/05/2022               7.68
# 1785               501.0  26/05/2022               7.07
# 2247               495.0  27/05/2022               7.63
# ...                  ...         ...                ...
# 20226                8.0  19/06/2022               8.00
# 20232                8.0  19/06/2022               7.50
# 20255               12.0  20/06/2022              12.00
# 20352                8.0  19/06/2022               8.00
# 20427                8.0  14/06/2022               8.00
#
#        calculated_host_listings_count  availability_365  number_of_reviews_ltm
# 1488                             17.0             256.0                  104.0
# 1674                              6.0             354.0                   19.0
# 1675                              6.0             346.0                   26.0
# 1785                             10.0             301.0                   70.0
# 2247                              1.0             342.0                   89.0
# ...                               ...               ...                    ...
# 20226                             2.0             333.0                    8.0
# 20232                             1.0             314.0                    8.0
# 20255                            45.0              64.0                   12.0
# 20352                             9.0             360.0                    8.0
# 20427                            16.0             365.0                    8.0
#
# [223 rows x 17 columns]

# %%
#Diagrama de caja: reviews_per_month.
fig6 = plt.figure(figsize =(5, 3))
plt.boxplot(data3["reviews_per_month"]) #boxplot() usa iqr
plt.title("Outliers de reviews_per_month")
plt.show()

# %%
#Valores extremos: límite superior y límite inferior.
#Variable: availability_365.
x7=data3["availability_365"]
LS7= x7.mean() + 3*x7.std()
LI7= x7.mean() - 3*x7.std()
print("Limite superior permitido", LS7)
print("Limite inferior permitido", LI7)
# Out:
# Limite superior permitido 612.4014586334399
# Limite inferior permitido -125.45042259116755

# %%
#Outliers de availability_365.
outliers_availability_365 = data3[(x7>LS7)|(x7<LI7)]
outliers_availability_365
# Out:
#            id                                 name   host_id host_name  \
# 15  2056638.0  Amplio y luminoso loft en CoyoacÃ¡n  10531228     Maria
#
#    neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 15             Unknown     CoyoacÃ¡n  19.35353  -99.16299  Entire home/apt
#
#      price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 15  1602.0             1.0               21.0  24/06/2018                0.2
#
#     calculated_host_listings_count  availability_365  number_of_reviews_ltm
# 15                             3.0            1290.0                    0.0

# %%
#Diagrama de caja: reviews_per_month.
fig7 = plt.figure(figsize =(5, 3))
plt.boxplot(data3["availability_365"]) #boxplot() usa iqr
plt.title("Outliers de availability_365")
plt.show()

# %% [markdown]
# Rango intercuartílico

# %%
#Valores extremos: límite superior y límite inferior.
#Variable: latitud.

p25x1=x1.quantile(0.25) #Q1
p75x1=x1.quantile(0.75) #Q3
iqrx1 = p75x1 - p25x1 #Q3-Q1

LS_iqr_x1 = p75x1 + 1.5*iqrx1
LI_iqr_x1 = p25x1 - 1.5*iqrx1
print("Limite superior permitido", LS_iqr_x1)
print("Limite inferior permitido", LI_iqr_x1)
# Out:
# Limite superior permitido 19.507845000000003
# Limite inferior permitido 19.303884999999994

# %%
#Outliers de latitud
outliers_latitud = data2[(x1>LS_iqr_x1)|(x1<LI_iqr_x1)]
outliers_latitud
# Out:
#                id                                               name  \
# 96       329776.0                                 HabitaciÃ³n Verde.
# 194      609594.0                                House in Xochimilco
# 206     1920070.0                  Mountain Oasis surrender by trees
# 213     1945351.0             Private room. Near COLMEX, UPN, FLACSO
# 277     3506037.0                          SUITES BOSQUES MEDICA SUR
# ...           ...                                                ...
# 21638  52622073.0  Departamento Viveros del Lago.\nEnfrente de la...
# 21646  33914551.0                                          Cozy depa
# 21652  39023239.0           Recamara privada cerca del metro Rosario
# 21656  16928664.0              Hermosa habitaciÃ³n con baÃ±o privado
# 21665  22107097.0                      GREAT & cozy flat in Satelite
#
#          host_id  host_name neighbourhood_group neighbourhood   latitude  \
# 96       1683373     Miguel             Unknown       Tlalpan   19.27510
# 194      2223274       Luis             Unknown    Xochimilco   19.26541
# 206      9953466   Gabriela             Unknown       Tlalpan   19.24444
# 213       340030   Griselda             Unknown       Tlalpan   19.28356
# 277     17650235    Chelita             Unknown     CoyoacÃ¡n   19.29966
# ...          ...        ...                 ...           ...        ...
# 21638   21515326    Roberto             Unknown  Azcapotzalco   19.52295
# 21646  256115671     Atilio             Unknown  Azcapotzalco   19.51632
# 21652  298373642  BenjamÃ­n             Unknown  Azcapotzalco   19.51389
# 21656  101147814     Sandra             Unknown  Azcapotzalco   19.50816
# 21665  387195495    Daniela             Unknown  Azcapotzalco  119.50787
#
#        longitude        room_type   price  minimum_nights  number_of_reviews  \
# 96     -99.17757     Private room   303.0             2.0               16.0
# 194    -99.11365  Entire home/apt   608.0            21.0               12.0
# 206    -99.17044     Private room   417.0             1.0                3.0
# 213    -99.21837     Private room   608.0             3.0                2.0
# 277    -99.15624     Private room   533.0             1.0                0.0
# ...          ...              ...     ...             ...                ...
# 21638  -99.22571  Entire home/apt  1000.0             1.0               25.0
# 21646  -99.22004  Entire home/apt   393.0             2.0               77.0
# 21652  -99.20757     Private room   300.0             2.0                0.0
# 21656  -99.22190     Private room   579.0             1.0                1.0
# 21665  -99.22067  Entire home/apt   897.0             2.0              107.0
#
#       last_review  reviews_per_month  calculated_host_listings_count  \
# 96     25/12/2021               0.27                             5.0
# 194    06/10/2020               0.14                             1.0
# 206    27/10/2019               0.05                             1.0
# 213    26/01/2018               0.04                             3.0
# 277    No_reviews               0.00                             3.0
# ...           ...                ...                             ...
# 21638  05/06/2022               2.92                             2.0
# 21646  02/06/2022               2.00                             1.0
# 21652  No_reviews               0.00                             1.0
# 21656  06/04/2018               0.02                             1.0
# 21665  07/02/2022               1.97                            11.0
#
#        availability_365  number_of_reviews_ltm
# 96                  0.0                    1.0
# 194               325.0                    0.0
# 206               365.0                    0.0
# 213               365.0                    0.0
# 277               365.0                    0.0
# ...                 ...                    ...
# 21638             334.0                   25.0
# 21646              55.0                   33.0
# 21652             176.0                    0.0
# 21656              87.0                    0.0
# 21665             314.0                   17.0
#
# [1132 rows x 17 columns]

# %%
#Valores extremos: límite superior y límite inferior.
#Variable: longitude.

p25x2=x2.quantile(0.25) #Q1
p75x2=x2.quantile(0.75) #Q3
iqrx2 = p75x2 - p25x2 #Q3-Q1

LS_iqr_x2 = p75x2 + 1.5*iqrx2
LI_iqr_x2 = p25x2 - 1.5*iqrx2
print("Limite superior permitido", LS_iqr_x2)
print("Limite inferior permitido", LI_iqr_x2)
# Out:
# Limite superior permitido -99.112735
# Limite inferior permitido -99.222695

# %%
#Outliers de longitud
outliers_longitud = data2[(x2>LS_iqr_x2)|(x2<LI_iqr_x2)]
outliers_longitud
# Out:
#                  id                                               name  \
# 1      3.579700e+04                                        Villa Dante
# 2      5.239058e+07  Casa en privada con  vigilancia, estacionamiento.
# 6      1.551198e+07                                 La casa de Abraham
# 7      3.477645e+07  â
#  The attic â
#  Panoramic garden 10 min Citi...
# 8      4.576710e+07  BONITO DEPARTAMENTO NUEVO  LOMAS DE  TECAMACHALCO
# ...             ...                                                ...
# 21663  4.588272e+07  Big/nice/YOGUI room, in relax & sure neighborhood
# 21664  6.180000e+17  CÃ³modo Departamento en Satelite-Echegaray con...
# 21666  4.061781e+07                                             Blanca
# 21667  5.700000e+17                   Casa LimÃ³n. Confort y seguridad
# 21668  3.717560e+07  Linda casa con enorme jardÃ­n en zona residenc...
#
#          host_id           host_name neighbourhood_group  \
# 1         153786                Dici             Unknown
# 2      424060909  Maria Carmen Marta             Unknown
# 6       93364273             Abraham             Unknown
# 7        2954577    Lazaro Alejandro             Unknown
# 8      371036285                Luis             Unknown
# ...          ...                 ...                 ...
# 21663   47070934           Alejandra             Unknown
# 21664  442065952             Ricardo             Unknown
# 21666   96471106         Mary Carmen             Unknown
# 21667   30446640              Ericka             Unknown
# 21668   51907431             Cecilia             Unknown
#
#                neighbourhood   latitude  longitude        room_type   price  \
# 1      Cuajimalpa de Morelos  19.382830 -99.271780  Entire home/apt  4056.0
# 2      Cuajimalpa de Morelos  19.395126 -99.277374     Private room   752.0
# 6             Miguel Hidalgo  19.410950 -99.244180     Private room   800.0
# 7             Miguel Hidalgo  19.426410 -99.225910     Private room  1779.0
# 8             Miguel Hidalgo  19.419470 -99.240630     Private room   500.0
# ...                      ...        ...        ...              ...     ...
# 21663           Azcapotzalco  19.501490 -99.228090     Private room   250.0
# 21664           Azcapotzalco  19.499980 -99.226010  Entire home/apt   673.0
# 21666           Azcapotzalco  19.507530 -99.225060  Entire home/apt   230.0
# 21667           Azcapotzalco  19.493360 -99.229090  Entire home/apt   690.0
# 21668           Azcapotzalco  19.490040 -99.230310  Entire home/apt  3228.0
#
#        minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 1                 1.0                0.0  No_reviews               0.00
# 2                 1.0                0.0  No_reviews               0.00
# 6                 1.0                1.0  19/03/2018               0.02
# 7                 1.0                5.0  14/03/2022               0.14
# 8                 7.0                0.0  No_reviews               0.00
# ...               ...                ...         ...                ...
# 21663             6.0                0.0  No_reviews               0.00
# 21664             1.0                3.0  29/05/2022               2.73
# 21666             1.0                5.0  31/12/2019               0.16
# 21667             3.0                0.0  No_reviews               0.00
# 21668             2.0               58.0  13/06/2022               1.66
#
#        calculated_host_listings_count  availability_365  number_of_reviews_ltm
# 1                                 1.0             363.0                    0.0
# 2                                 1.0             365.0                    0.0
# 6                                 1.0             179.0                    0.0
# 7                                 4.0             222.0                    1.0
# 8                                 1.0             365.0                    0.0
# ...                               ...               ...                    ...
# 21663                             1.0             364.0                    3.0
# 21664                            79.0             314.0                    3.0
# 21666                             4.0             140.0                    0.0
# 21667                             1.0             354.0                    0.0
# 21668                             1.0              10.0                   20.0
#
# [2700 rows x 17 columns]

# %%
#Valores extremos: límite superior y límite inferior.
#Variable: price.

p25x3=x3.quantile(0.25) #Q1
p75x3=x3.quantile(0.75) #Q3
iqrx3 = p75x3 - p25x3 #Q3-Q1

LS_iqr_x3 = p75x3 + 1.5*iqrx3
LI_iqr_x3 = p25x3 - 1.5*iqrx3
print("Limite superior permitido", LS_iqr_x3)
print("Limite inferior permitido", LI_iqr_x3)
# Out:
# Limite superior permitido 2960.0
# Limite inferior permitido -976.0

# %%
#Outliers de price
outliers_price = data2[(x3>LS_iqr_x3)|(x3<LI_iqr_x3)]
outliers_price
# Out:
#                  id                                               name  \
# 1      3.579700e+04                                        Villa Dante
# 4      4.461600e+04                                  CONDESA HAUS  B&B
# 28     1.070780e+05                                 NEW  DESIGNER LOFT
# 31     1.657720e+05       BEST 4BR 4 BH HOUSE IN S. MIGUEL CHAPULTEPEC
# 39     2.093036e+06                Departamento 2 dormitorios x Antara
# ...             ...                                                ...
# 21540  1.377077e+07                   Estudiantes parada Tec AnÃ¡huac.
# 21567  3.603670e+07         Departamento Remodelado en Renta Echegaray
# 21598  5.450000e+17  Cheerful 4 bedroom residence in nice neighborhood
# 21609  6.490000e+17         4 habitaciones 11 camas en casa compartida
# 21668  3.717560e+07  Linda casa con enorme jardÃ­n en zona residenc...
#
#          host_id                           host_name neighbourhood_group  \
# 1         153786                                Dici             Unknown
# 4         196253  Condesa Haus Bed & Breakfast  CDMX             Unknown
# 28        540705                              Andrea             Unknown
# 31        790208                          Maria Jose             Unknown
# 39       3083561                            Federico             Unknown
# ...          ...                                 ...                 ...
# 21540   80804417                           Luz Elena             Unknown
# 21567  271110724                                  Il             Unknown
# 21598  441385756                            Fernando             Unknown
# 21609  138094276                               Erika             Unknown
# 21668   51907431                             Cecilia             Unknown
#
#                neighbourhood  latitude  longitude        room_type    price  \
# 1      Cuajimalpa de Morelos  19.38283  -99.27178  Entire home/apt   4056.0
# 4                CuauhtÃ©moc  19.41162  -99.17794  Entire home/apt  18000.0
# 28            Miguel Hidalgo  19.43211  -99.19327  Entire home/apt   3796.0
# 31            Miguel Hidalgo  19.40826  -99.18659  Entire home/apt   3837.0
# 39            Miguel Hidalgo  19.44178  -99.20202     Private room   3130.0
# ...                      ...       ...        ...              ...      ...
# 21540      Gustavo A. Madero  19.53352  -99.19122     Private room   4700.0
# 21567           Azcapotzalco  19.48724  -99.22519  Entire home/apt  10000.0
# 21598         Miguel Hidalgo  19.42275  -99.25692  Entire home/apt   5000.0
# 21609             Iztapalapa  19.39786  -99.04539     Private room   3500.0
# 21668           Azcapotzalco  19.49004  -99.23031  Entire home/apt   3228.0
#
#        minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 1                 1.0                0.0  No_reviews               0.00
# 4                 1.0               56.0  05/06/2022               0.43
# 28                4.0               10.0  05/10/2019               0.14
# 31                2.0              278.0  30/05/2022               2.09
# 39                1.0                0.0  No_reviews               0.00
# ...               ...                ...         ...                ...
# 21540            36.0                0.0  No_reviews               0.00
# 21567           180.0                0.0  No_reviews               0.00
# 21598             3.0                0.0  No_reviews               0.00
# 21609             1.0                0.0  No_reviews               0.00
# 21668             2.0               58.0  13/06/2022               1.66
#
#        calculated_host_listings_count  availability_365  number_of_reviews_ltm
# 1                                 1.0             363.0                    0.0
# 4                                11.0             347.0                    7.0
# 28                                3.0             208.0                    0.0
# 31                                6.0             231.0                    8.0
# 39                                1.0             365.0                    0.0
# ...                               ...               ...                    ...
# 21540                             1.0             365.0                    0.0
# 21567                             1.0             365.0                    0.0
# 21598                             1.0             365.0                    0.0
# 21609                            11.0             359.0                    0.0
# 21668                             1.0              10.0                   20.0
#
# [1511 rows x 17 columns]

# %%
#Valores extremos: límite superior y límite inferior.
#Variable: minimum_nights.

p25x4=x4.quantile(0.25) #Q1
p75x4=x4.quantile(0.75) #Q3
iqrx4 = p75x4 - p25x4 #Q3-Q1

LS_iqr_x4 = p75x4 + 1.5*iqrx4
LI_iqr_x4 = p25x4 - 1.5*iqrx4
print("Limite superior permitido", LS_iqr_x4)
print("Limite inferior permitido", LI_iqr_x4)
# Out:
# Limite superior permitido 6.0
# Limite inferior permitido -2.0

# %%
#Outliers de minimum_nights
outliers_minimum_nights = data2[(x4>LS_iqr_x4)|(x4<LI_iqr_x4)]
outliers_minimum_nights
# Out:
#                id                                               name  \
# 0        826691.0                    Suite 7 - Suites Condesa Mexico
# 8      45767104.0  BONITO DEPARTAMENTO NUEVO  LOMAS DE  TECAMACHALCO
# 16        58955.0                 Entire beautiful duplex in la Roma
# 27        70644.0   Beautiful light Studio Coyoacan- full equipped !
# 41       187030.0      Spacious apt with the best rooftop in Condesa
# ...           ...                                                ...
# 21577  46948276.0                Habitaciones con ambiente tranquilo
# 21594  41901466.0    Alojamiento a 10 minutos de Ã©l Aeropuerto CDMX
# 21600  26589089.0                          Nueva habitacion en renta
# 21628  23056362.0               suite en la herradura la mejor vista
# 21632  16426788.0   Private rooms - 2 blocks from Anahuac University
#
#          host_id host_name neighbourhood_group          neighbourhood  \
# 0        4326326   Rodrigo             Unknown            CuauhtÃ©moc
# 8      371036285      Luis             Unknown         Miguel Hidalgo
# 16        282620     Laura             Unknown            CuauhtÃ©moc
# 27        212109    Trisha             Unknown              CoyoacÃ¡n
# 41        899360    Julian             Unknown            CuauhtÃ©moc
# ...          ...       ...                 ...                    ...
# 21577  379425976    Gisela             Unknown      Gustavo A. Madero
# 21594  325761667     Isaac             Unknown      Gustavo A. Madero
# 21600   62576597      Lupe             Unknown  Cuajimalpa de Morelos
# 21628  170621268  Carolina             Unknown         Miguel Hidalgo
# 21632  107690480   Leticia             Unknown  Cuajimalpa de Morelos
#
#        latitude  longitude        room_type   price  minimum_nights  \
# 0      19.40915  -99.17321  Entire home/apt   850.0           180.0
# 8      19.41947  -99.24063     Private room   500.0             7.0
# 16     19.42113  -99.15955  Entire home/apt  2019.0             7.0
# 27     19.35448  -99.16217  Entire home/apt  1197.0             7.0
# 41     19.41057  -99.17730  Entire home/apt  2142.0            14.0
# ...         ...        ...              ...     ...             ...
# 21577  19.50459  -99.04702      Shared room   210.0            30.0
# 21594  19.47178  -99.05042     Private room   406.0            10.0
# 21600  19.40953  -99.26700     Private room   500.0             7.0
# 21628  19.42308  -99.25948     Private room   317.0             7.0
# 21632  19.40767  -99.26095     Private room   435.0            30.0
#
#        number_of_reviews last_review  reviews_per_month  \
# 0                   18.0  11/05/2019               0.17
# 8                    0.0  No_reviews               0.00
# 16                  45.0  06/01/2022               0.35
# 27                 112.0  20/06/2022               0.89
# 41                  98.0  28/05/2022               0.76
# ...                  ...         ...                ...
# 21577                0.0  No_reviews               0.00
# 21594                0.0  No_reviews               0.00
# 21600                1.0  08/11/2018               0.02
# 21628                0.0  No_reviews               0.00
# 21632                1.0  06/07/2017               0.02
#
#        calculated_host_listings_count  availability_365  number_of_reviews_ltm
# 0                                 6.0             325.0                    0.0
# 8                                 1.0             365.0                    0.0
# 16                                1.0             351.0                    3.0
# 27                                3.0             153.0                    8.0
# 41                                6.0             171.0                    1.0
# ...                               ...               ...                    ...
# 21577                             1.0             365.0                    0.0
# 21594                             2.0             358.0                    0.0
# 21600                             1.0             173.0                    0.0
# 21628                             1.0              90.0                    0.0
# 21632                             2.0             363.0                    0.0
#
# [1679 rows x 17 columns]

# %%
#Valores extremos: límite superior y límite inferior.
#Variable: number_of_reviews.

p25x5=x5.quantile(0.25) #Q1
p75x5=x5.quantile(0.75) #Q3
iqrx5 = p75x5 - p25x5 #Q3-Q1

LS_iqr_x5 = p75x5 + 1.5*iqrx5
LI_iqr_x5 = p25x5 - 1.5*iqrx5
print("Limite superior permitido", LS_iqr_x5)
print("Limite inferior permitido", LI_iqr_x5)
# Out:
# Limite superior permitido 86.0
# Limite inferior permitido -50.0

# %%
#Outliers de minimum_nights
outliers_number_of_reviews = data2[(x5>LS_iqr_x5)|(x5<LI_iqr_x5)]
outliers_number_of_reviews
# Out:
#                id                                               name  \
# 9        832805.0      ROOMS CASA INDIGO WITH TERRACE AT CITY CENTER
# 23       883511.0  Cozy House with Roofterrace group 29 pax Cente...
# 27        70644.0   Beautiful light Studio Coyoacan- full equipped !
# 30       913084.0                 15 blocks from Paseo de la Reforma
# 31       165772.0       BEST 4BR 4 BH HOUSE IN S. MIGUEL CHAPULTEPEC
# ...           ...                                                ...
# 21402  19628292.0  15 min Aeropuerto AutÃ³dromo Palacio de los de...
# 21431  24064511.0  ð³ï¸âðCLOSE TO AIRPORT & DOWNTOWN @IDE...
# 21445  22973104.0  Depa1 FÃ¡cil Acceso Aeropuerto, Metro,Bosque A...
# 21615  25090111.0  CÃMODO APARTAMENTO PLANTA ALTA, 20min aeropuerto
# 21665  22107097.0                      GREAT & cozy flat in Satelite
#
#          host_id   host_name neighbourhood_group      neighbourhood  \
# 9        3777702     Abraham             Unknown        CuauhtÃ©moc
# 23       3777702     Abraham             Unknown        CuauhtÃ©moc
# 27        212109      Trisha             Unknown          CoyoacÃ¡n
# 30       4647293     Martina             Unknown     Miguel Hidalgo
# 31        790208  Maria Jose             Unknown     Miguel Hidalgo
# ...          ...         ...                 ...                ...
# 21402  138094276       Erika             Unknown         Iztapalapa
# 21431  160773275     Gonzalo             Unknown  Gustavo A. Madero
# 21445  170284149      Eunice             Unknown  Gustavo A. Madero
# 21615  127271180     VÃ­ctor             Unknown  Gustavo A. Madero
# 21665  387195495     Daniela             Unknown       Azcapotzalco
#
#         latitude  longitude        room_type   price  minimum_nights  \
# 9       19.44262  -99.14566     Private room   444.0             1.0
# 23      19.44207  -99.14797  Entire home/apt  2827.0             1.0
# 27      19.35448  -99.16217  Entire home/apt  1197.0             7.0
# 30      19.43956  -99.17263  Entire home/apt  2057.0             2.0
# 31      19.40826  -99.18659  Entire home/apt  3837.0             2.0
# ...          ...        ...              ...     ...             ...
# 21402   19.39794  -99.04350     Private room   350.0             1.0
# 21431   19.46194  -99.05415  Entire home/apt   401.0             2.0
# 21445   19.45781  -99.05398  Entire home/apt   303.0             1.0
# 21615   19.48893  -99.06681  Entire home/apt   450.0             1.0
# 21665  119.50787  -99.22067  Entire home/apt   897.0             2.0
#
#        number_of_reviews last_review  reviews_per_month  \
# 9                  125.0  26/01/2022               1.08
# 23                 209.0  06/06/2022               1.83
# 27                 112.0  20/06/2022               0.89
# 30                 139.0  13/06/2022               1.25
# 31                 278.0  30/05/2022               2.09
# ...                  ...         ...                ...
# 21402              144.0  13/06/2022               2.54
# 21431              100.0  04/05/2022               1.96
# 21445              136.0  05/06/2022               2.56
# 21615              158.0  12/05/2022               3.31
# 21665              107.0  07/02/2022               1.97
#
#        calculated_host_listings_count  availability_365  number_of_reviews_ltm
# 9                                 6.0             288.0                    2.0
# 23                                6.0             249.0                   27.0
# 27                                3.0             153.0                    8.0
# 30                                2.0             180.0                   27.0
# 31                                6.0             231.0                    8.0
# ...                               ...               ...                    ...
# 21402                            11.0             361.0                   17.0
# 21431                             5.0             323.0                   11.0
# 21445                             2.0             359.0                   24.0
# 21615                             1.0             362.0                   38.0
# 21665                            11.0             314.0                   17.0
#
# [2281 rows x 17 columns]

# %%
#Valores extremos: límite superior y límite inferior.
#Variable: reviews_per_month.

p25x6=x6.quantile(0.25) #Q1
p75x6=x6.quantile(0.75) #Q3
iqrx6 = p75x6 - p25x6 #Q3-Q1

LS_iqr_x6 = p75x6 + 1.5*iqrx6
LI_iqr_x6 = p25x6 - 1.5*iqrx6
print("Limite superior permitido", LS_iqr_x6)
print("Limite inferior permitido", LI_iqr_x6)
# Out:
# Limite superior permitido 4.574999999999999
# Limite inferior permitido -2.5849999999999995

# %%
#Outliers de reviews_per_month
outliers_reviews_per_month = data2[(x6>LS_iqr_x6)|(x6<LI_iqr_x6)]
outliers_reviews_per_month
# Out:
#                  id                                               name  \
# 36     2.084093e+06                         5 min from CDMXÂ´s airport
# 214    2.863598e+06     Cozy, sunny room. Located in the heart of CDMX
# 298    3.635953e+06                  Nice Loft in the heart of Polanco
# 337    3.849434e+06       15th floor apartment Roma Norte, Mexico City
# 718    6.855833e+06  Big Window, Charming & Cozy Little Apt in La Roma
# ...             ...                                                ...
# 20655  6.360000e+17  IncreÃ­ble Alojamiento en Contenedor MarÃ­timo...
# 20735  6.440000e+17  IncreÃ­ble Alojamiento en Contenedor Maritimo ...
# 21219  5.540000e+17  FantÃ¡stico Departamento de 2 Recamaras en Sat...
# 21530  6.230000e+17    Tranquilo departamento con  servicios incluidos
# 21642  5.540000e+17  Moderno Departamento en Satelite-Echegaray con...
#
#          host_id              host_name neighbourhood_group  \
# 36      10644799                 Benito             Unknown
# 214     13793390                  Mario             Unknown
# 298     18334496                  Nando             Unknown
# 337     10731286                 Larren             Unknown
# 718     14889247  AndrÃ©s And Francisco             Unknown
# ...          ...                    ...                 ...
# 20655  348389387                 Daniel             Unknown
# 20735  348389387                 Daniel             Unknown
# 21219  442065952                Ricardo             Unknown
# 21530  191626918                   AlÃ­             Unknown
# 21642  442065952                Ricardo             Unknown
#
#              neighbourhood   latitude  longitude        room_type   price  \
# 36     Venustiano Carranza  19.439490 -99.087690  Entire home/apt   446.0
# 214         Benito JuÃ¡rez  19.392130 -99.172070     Private room   344.0
# 298         Miguel Hidalgo  19.432150 -99.188510  Entire home/apt  1620.0
# 337            CuauhtÃ©moc  19.420440 -99.166820  Entire home/apt  1241.0
# 718            CuauhtÃ©moc  19.409720 -99.160360  Entire home/apt  1033.0
# ...                    ...        ...        ...              ...     ...
# 20655         Azcapotzalco  19.478848 -99.189362  Entire home/apt   320.0
# 20735         Azcapotzalco  19.479700 -99.190000  Entire home/apt   282.0
# 21219         Azcapotzalco  19.499702 -99.225136  Entire home/apt   766.0
# 21530         Azcapotzalco  19.507942 -99.221069     Private room   350.0
# 21642         Azcapotzalco  19.499702 -99.225136  Entire home/apt   618.0
#
#        minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 36                1.0              562.0  28/05/2022               5.92
# 214               2.0               10.0  17/06/2022               5.08
# 298               1.0              548.0  17/06/2022               5.70
# 337               2.0              348.0  06/06/2022               5.52
# 718               1.0              438.0  16/06/2022               5.30
# ...               ...                ...         ...                ...
# 20655             1.0                5.0  09/06/2022               5.00
# 20735             1.0                5.0  19/06/2022               5.00
# 21219             1.0               25.0  12/06/2022               5.77
# 21530             1.0                7.0  19/06/2022               5.68
# 21642             1.0               25.0  12/06/2022               6.82
#
#        calculated_host_listings_count  availability_365  number_of_reviews_ltm
# 36                                6.0             354.0                   24.0
# 214                               1.0             274.0                   10.0
# 298                               4.0              76.0                   62.0
# 337                               2.0             314.0                   50.0
# 718                               2.0             259.0                   51.0
# ...                               ...               ...                    ...
# 20655                             4.0             316.0                    5.0
# 20735                             4.0             324.0                    5.0
# 21219                            79.0             343.0                   25.0
# 21530                             1.0             365.0                    7.0
# 21642                            79.0             359.0                   25.0
#
# [990 rows x 17 columns]

# %%
#Valores extremos: límite superior y límite inferior.
#Variable: availability_365.

p25x7=x7.quantile(0.25) #Q1
p75x7=x7.quantile(0.75) #Q3
iqrx7 = p75x7 - p25x7 #Q3-Q1

LS_iqr_x7 = p75x7 + 1.5*iqrx7
LI_iqr_x7 = p25x7 - 1.5*iqrx7
print("Limite superior permitido", LS_iqr_x7)
print("Limite inferior permitido", LI_iqr_x7)
# Out:
# Limite superior permitido 672.5
# Limite inferior permitido -171.5

# %%
#Outliers de availability_365
outliers_availability_365 = data2[(x7>LS_iqr_x7)|(x7<LI_iqr_x7)]
outliers_availability_365
# Out:
#            id                                 name   host_id host_name  \
# 15  2056638.0  Amplio y luminoso loft en CoyoacÃ¡n  10531228     Maria
#
#    neighbourhood_group neighbourhood  latitude  longitude        room_type  \
# 15             Unknown     CoyoacÃ¡n  19.35353  -99.16299  Entire home/apt
#
#      price  minimum_nights  number_of_reviews last_review  reviews_per_month  \
# 15  1602.0             1.0               21.0  24/06/2018                0.2
#
#     calculated_host_listings_count  availability_365  number_of_reviews_ltm
# 15                             3.0            1290.0                    0.0

# %% [markdown]
# Sustitución de Outliers

# %%
#Segunda sustitución: minimum_nights
#Método: rango intercuartílico
data3=data2[(x4<=LS_iqr_x4)&(x4>=LI_iqr_x4)] #Obtenemos datos sin outliers de minimum_nigths del DataFrame
data3["minimum_nights"]=data3["minimum_nights"].fillna(round(data2["minimum_nights"].mode(),0))
# Out:
# C:\Users\aremy\AppData\Local\Temp\ipykernel_32568\4233478953.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3["minimum_nights"]=data3["minimum_nights"].fillna(round(data2["minimum_nights"].mode(),0))

# %%
#Tercera variable: number_of_reviews
#Método: desviación estándar
data3=data2[(x5<=LS5)&(x5>=LI5)] #Obtenemos datos sin outliers de number_of_reviews del DataFrame
data3["number_of_reviews"]=data3["number_of_reviews"].fillna(round(data2["number_of_reviews"].median(),0))
# Out:
# C:\Users\aremy\AppData\Local\Temp\ipykernel_32568\3899938042.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3["number_of_reviews"]=data3["number_of_reviews"].fillna(round(data2["number_of_reviews"].median(),0))

# %%
#Cuarta variable: reviews_per_month
#Método: rango intercuartílico
data3=data2[(x6<=LS_iqr_x6)&(x6>=LI_iqr_x6)] #Obtenemos datos sin outliers de reviews_per_month del DataFrame
data3["reviews_per_month"]=data3["reviews_per_month"].fillna(round(data2["reviews_per_month"].median(),2))
# Out:
# C:\Users\aremy\AppData\Local\Temp\ipykernel_32568\1568465726.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3["reviews_per_month"]=data3["reviews_per_month"].fillna(round(data2["reviews_per_month"].median(),2))

# %%
#Quinta variable: availability_365
#Método: desviación estándar
data3=data2[(x7<=LS7)&(x7>=LI7)] #Obtenemos datos sin outliers de availability_365 del DataFrame
data3["availability_365"]=data3["availability_365"].fillna(round(data2["availability_365"].mean(),0))
# Out:
# C:\Users\aremy\AppData\Local\Temp\ipykernel_32568\1267522239.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3["availability_365"]=data3["availability_365"].fillna(round(data2["availability_365"].mean(),0))

# %% [markdown]
# Generar .csv con datos limpios

# %%
#Convertir DataFrame limpio a CSV
clean_airbnb=data3.copy()
clean_airbnb
clean_airbnb.to_csv("clean_airbnb - Mexico.csv")

# %% [markdown]
# Filtros por tipo de habitación

# %%
#Filtros por tipo de habitación en varios csv diferentes para usarlo en Minitab
entire_home_apt_mex = data3[(data3["room_type"] == "Entire home/apt")]
entire_home_apt_mex.to_csv("Entire home apt - Mex.csv")

# %%
hotel_room_mex = data3[(data3["room_type"] == "Hotel room")]
hotel_room_mex.to_csv("Hotel room - Mex.csv")

# %%
priv_room_mex = data3[(data3["room_type"] == "Private room")]
priv_room_mex.to_csv("Private room - Mex.csv")

# %%
shared_room_mex = data3[(data3["room_type"] == "Shared room")]
shared_room_mex.to_csv("Shared room - Mex.csv")
